# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('noahs-csv/noahs-customers.csv')

# %%
df.shape
# Out:
# (11080, 6)

# %%
df.head()
# Out:
#    customerid              name          address             citystatezip  \
# 0        1001        Jack Quinn    201 E Park St    Los Angeles, CA 91343
# 1        1002      David Powell   224C Tysens Ln  Staten Island, NY 10306
# 2        1003      Carrie Green  1608 W 53rd Way          Tampa, FL 33614
# 3        1004     Steven Miller    178½ E 7th St      Manhattan, NY 10009
# 4        1005  Christine Powers   270 W 242nd St          Bronx, NY 10463
#
#     birthdate         phone
# 0  1960-05-14  805-287-8515
# 1  1978-04-04  516-768-1652
# 2  1969-01-21  727-209-0470
# 3  1953-08-17  607-941-9563
# 4  1983-06-06  212-759-9043

# %%
number_dictionary = {
    'abc': 2,
    'def':3,
    'ghi':4,
    'jkl':5,
    'mno':6,
    'pqrs':7,
    'tuv':8,
    'wxyz':9
}

# %%
df['phone_clean'] = df.phone.str.replace('-', '')

# %%
df['last_name'] = df['name'].apply(lambda x: x.split()[-1].lower())

# %%
df['last_name'] = df['last_name'].str.split('')

# %%
df.head()
# Out:
#    customerid              name          address             citystatezip  \
# 0        1001        Jack Quinn    201 E Park St    Los Angeles, CA 91343
# 1        1002      David Powell   224C Tysens Ln  Staten Island, NY 10306
# 2        1003      Carrie Green  1608 W 53rd Way          Tampa, FL 33614
# 3        1004     Steven Miller    178½ E 7th St      Manhattan, NY 10009
# 4        1005  Christine Powers   270 W 242nd St          Bronx, NY 10463
#
#     birthdate         phone phone_clean               last_name
# 0  1960-05-14  805-287-8515  8052878515     [, q, u, i, n, n, ]
# 1  1978-04-04  516-768-1652  5167681652  [, p, o, w, e, l, l, ]
# 2  1969-01-21  727-209-0470  7272090470     [, g, r, e, e, n, ]
# 3  1953-08-17  607-941-9563  6079419563  [, m, i, l, l, e, r, ]
# 4  1983-06-06  212-759-9043  2127599043  [, p, o, w, e, r, s, ]

# %%
df.head(6)
# Out:
#    customerid              name            address             citystatezip  \
# 0        1001        Jack Quinn      201 E Park St    Los Angeles, CA 91343
# 1        1002      David Powell     224C Tysens Ln  Staten Island, NY 10306
# 2        1003      Carrie Green    1608 W 53rd Way          Tampa, FL 33614
# 3        1004     Steven Miller      178½ E 7th St      Manhattan, NY 10009
# 4        1005  Christine Powers     270 W 242nd St          Bronx, NY 10463
# 5        1006    Amanda Ramirez  183-48 Camden Ave   Saint Albans, NY 11412
#
#     birthdate         phone phone_clean                  last_name
# 0  1960-05-14  805-287-8515  8052878515        [, q, u, i, n, n, ]
# 1  1978-04-04  516-768-1652  5167681652     [, p, o, w, e, l, l, ]
# 2  1969-01-21  727-209-0470  7272090470        [, g, r, e, e, n, ]
# 3  1953-08-17  607-941-9563  6079419563     [, m, i, l, l, e, r, ]
# 4  1983-06-06  212-759-9043  2127599043     [, p, o, w, e, r, s, ]
# ...

# %%
number_list = []
for surname in df.last_name:
    name_values = []
    for char in surname:
        for key in number_dictionary:
            if char == '':
                pass
            elif char in key:
                name_values.append(number_dictionary[key])
                
    number_list.append(name_values)

# %%
number_list
# Out:
# [[7, 8, 4, 6, 6],
#  [7, 6, 9, 3, 5, 5],
#  [4, 7, 3, 3, 6],
#  [6, 4, 5, 5, 3, 7],
#  [7, 6, 9, 3, 7, 7],
#  [7, 2, 6, 4, 7, 3, 9],
#  [2, 6, 5, 5, 4, 6, 7],
#  [7, 8, 3, 8, 3, 6, 7],
#  [3, 6, 9, 5, 3, 7],
#  [5, 6, 4, 6, 7, 6, 6],
#  [2, 7, 6, 9, 6],
#  [9, 2, 5, 5, 3, 7],
#  [2, 6, 6, 5],
#  [7, 4, 6, 7],
#  [2, 2, 6, 7, 2, 3, 5, 5],
#  [6, 6, 6, 7, 3],
#  [7, 6, 4, 8, 4],
#  [7, 8, 3, 8, 3, 6, 7],
#  [6, 6, 7, 7, 4, 7],
#  [7, 2, 7, 5, 7],
#  [9, 7, 4, 4, 4, 8],
#  [2, 4, 2, 8, 3, 9],
#  [9, 2, 8, 5, 4, 6, 7],
#  [4, 2, 5, 8, 2, 6],
#  [2, 4, 2, 8, 3, 9],
#  [4, 4, 2, 7, 6, 6],
#  [7, 6, 2, 3, 7, 8, 7],
#  [7, 8, 7, 6, 6, 4],
#  [7, 8, 5, 5, 4, 8, 2, 6],
#  [3, 7, 3, 6, 2, 4],
#  [6, 6, 2, 5, 3],
#  [3, 5, 6, 9, 3, 7, 7],
#  [5, 2, 2, 6, 2, 7],
#  [9, 7, 4, 4, 4, 8],
#  [2, 3, 5, 5],
#  [4, 2, 4, 6, 3, 7],
#  [5, 6, 6, 3, 7],
#  [4, 6, 6, 3, 9],
#  [6, 4, 5, 5, 3, 7],
#  [4, 4, 4],
#  [7, 6, 4, 8, 4],
#  [5, 6, 6, 3, 7],
#  [3, 2, 8, 4, 7],
#  [3, 5, 6, 7, 3, 7],
# ...

# %%
len(number_list)
# Out:
# 11080

# %%
df.head()
# Out:
#    customerid              name          address             citystatezip  \
# 0        1001        Jack Quinn    201 E Park St    Los Angeles, CA 91343
# 1        1002      David Powell   224C Tysens Ln  Staten Island, NY 10306
# 2        1003      Carrie Green  1608 W 53rd Way          Tampa, FL 33614
# 3        1004     Steven Miller    178½ E 7th St      Manhattan, NY 10009
# 4        1005  Christine Powers   270 W 242nd St          Bronx, NY 10463
#
#     birthdate         phone phone_clean               last_name phone_by_name
# 0  1960-05-14  805-287-8515  8052878515     [, q, u, i, n, n, ]         78466
# 1  1978-04-04  516-768-1652  5167681652  [, p, o, w, e, l, l, ]        769355
# 2  1969-01-21  727-209-0470  7272090470     [, g, r, e, e, n, ]         47336
# 3  1953-08-17  607-941-9563  6079419563  [, m, i, l, l, e, r, ]        645537
# 4  1983-06-06  212-759-9043  2127599043  [, p, o, w, e, r, s, ]        769377

# %%
num_join_list = []
for phone_num in number_list:
    if phone_num == '':
        pass
    else:
       num_join_list.append(''.join(map(str, phone_num)))

# %%
num_join_list
# Out:
# ['78466',
#  '769355',
#  '47336',
#  '645537',
#  '769377',
#  '7264739',
#  '2655467',
#  '7838367',
#  '369537',
#  '5646766',
#  '27696',
#  '925537',
#  '2665',
#  '7467',
#  '22672355',
#  '66673',
#  '76484',
#  '7838367',
#  '667747',
#  '72757',
#  '974448',
#  '242839',
#  '9285467',
#  '425826',
#  '242839',
#  '442766',
#  '7623787',
#  '787664',
#  '78554826',
#  '373624',
#  '66253',
#  '3569377',
#  '522627',
#  '974448',
#  '2355',
#  '424637',
#  '56637',
#  '46639',
#  '645537',
#  '444',
#  '76484',
#  '56637',
#  '32847',
#  '356737',
#  '94554267',
#  '27696464',
#  '76246766',
#  '6246639',
#  '667866',
#  '82536242',
#  '47337',
#  '66825',
#  '69367',
#  '2622',
#  '76255',
#  '56637',
#  '78663',
#  '3673',
#  '229837',
#  '276729',
#  '356737',
#  '226767',
#  '66673',
#  '22884782',
#  '62269',
#  '3489437253',
#  '2789',
#  '7429',
#  '483766',
#  '437626339',
#  '76484',
#  '7839278',
#  '645537',
#  '6252844546',
#  '76246766',
#  '2653626',
#  '57',
# ...

# %%
df = df.assign(phone_by_name=num_join_list)

# %%
df.head()
# Out:
#    customerid              name          address             citystatezip  \
# 0        1001        Jack Quinn    201 E Park St    Los Angeles, CA 91343
# 1        1002      David Powell   224C Tysens Ln  Staten Island, NY 10306
# 2        1003      Carrie Green  1608 W 53rd Way          Tampa, FL 33614
# 3        1004     Steven Miller    178½ E 7th St      Manhattan, NY 10009
# 4        1005  Christine Powers   270 W 242nd St          Bronx, NY 10463
#
#     birthdate         phone phone_clean               last_name phone_by_name
# 0  1960-05-14  805-287-8515  8052878515     [, q, u, i, n, n, ]         78466
# 1  1978-04-04  516-768-1652  5167681652  [, p, o, w, e, l, l, ]        769355
# 2  1969-01-21  727-209-0470  7272090470     [, g, r, e, e, n, ]         47336
# 3  1953-08-17  607-941-9563  6079419563  [, m, i, l, l, e, r, ]        645537
# 4  1983-06-06  212-759-9043  2127599043  [, p, o, w, e, r, s, ]        769377

# %%
detective_name = np.where(df.phone_clean.eq(df.phone_by_name))

# %%
detective_name
# Out:
# (array([2187]),)

# %%
df.iloc[2187]
# Out:
# customerid                                     3188
# name                                 Sam Guttenberg
# address                               221 Banker St
# citystatezip                     Brooklyn, NY 11222
# birthdate                                1998-05-30
# phone                                  488-836-2374
# phone_clean                              4888362374
# last_name        [, g, u, t, t, e, n, b, e, r, g, ]
# phone_by_name                            4888362374
# Name: 2187, dtype: object

# %%
df.phone_int = num_join_list

# %%
df['phone_clean'] = df.phone_clean.astype(str)
df['phone_by_name'] = df.phone_by_name.astype(str)

# %%
df.head()

# %%
match = df.phone_clean.eq(df.phone_by_name)
match.nunique()

# %%
match = df.phone_clean.eq(df.phone_by_name)
match.nunique()

# %%
df.phone_clean.dtype

# %%
detective_name

# %%
z = df.num_int[0]
dd =  int(''.join(map(str, z)))

# %%
s = ''.join(t)
s

# %%
df.head()

# %%
df_short_list = df.loc[df.name.str.len()==12]

# %%
first_name = df_short_list.name[1]
first_name

# %%
number_dictionary['abc']

# %%
'd' in number_dictionary.keys()

# %%
hey

# %%
first_number = []
for letter in first_name:
    if letter in number_dictionary.keys():
        first_number.append(number_dictionary.values())

# %%
short_list[0].

# %%
num_lis = []
for name in df.name:
    name.split()

# %%
df['phone_to_text'] =

# %%
if df.name in number_dictionary:
    print(ok)

# %%
len(df['phone'][0])

# %%
df['name'].head()

# %%
df['name'].max()

# %%
df.name.str.len().max()

# %%
short_list = df.loc[df.name.str.len()==12]

# %%
df.iloc[1031]

# %%
np.where(df.name.str.len().max() == 30,df['name'])
